# %% [markdown]
# General Pipeline:
#
# <ul>
# Loading and performing Segmentation:
#
#     1.) install dependecies and write imports
#     2.) Load Pretrained model
#     3.) Using the pretrained model, get some inference on how it would perform on a single image from the medical dataset
#     4.) Download dataset-look for high quality professionaly labeled datasets with ground truths
#     5.) Predict a ventricle mask reading an image from the data set and preproccess it (resize photo, normalize, convert to appropriate colour scaling for the model)
#     6.)Specify non-binary classifications(more than one), i.e "background", "left ventricle", "right ventricle",....
#     7.)Display test image and an overlay with th epredicted mask as a montage
#
# Prepare Data for Training
#
#     1.) Convert to RGB, Resize, Normalize, to tensor(Matrix representation) using training and eval objects for the data set
#     2. )Read and manage label images
#     3. )Partition for Train, val, test 80/10/10 split
#     4. ) augement train/val/test data if dataset small
#     5. )load Dataset into dataloaders
#
# Define Network architecture & training parameters/hyperparametrs
#
# Train
#
# Test
#
# Evaluate segmentation metric & Dice score
#
#
# Explainability
#
#     1.) Using GRAD-CAM, you can see which areas of an input image the network relies on to make its classification and segmentation masks.
#     2.) Load an image from the testdata and preprocess it accordingly then analze the results of appling GRAD-CAM
#
#
# Document Work
# </ul>

# %% [markdown]
# #Weight map:
